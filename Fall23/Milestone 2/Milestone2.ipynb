# %% [markdown]
# # CMPS 4010
# ## Milestone 2: Naive Model to Predict Volatility
# ### By Alex Olteanu and Shira Rozenthal

# %% [markdown]
# ### Setup

# %%
# ALEX CELL: Load the data.
from google.colab import drive

drive.mount('/content/drive')

# %cd /content/drive/My Drive/Tulane_CS/CMPS_4010/Milestones/optiver-realized-volatility-prediction/
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1DoZUk_FnkQR4z_AuHH3E7aPqa-ZezMKV/Milestones/optiver-realized-volatility-prediction

# %%
# # SHIRA CELL: Load the data.
# from google.colab import drive

# drive.mount('/content/drive')

# %cd /content/drive/My Drive/TULANE/FALL2023/CMPS4010/Milestones/optiver-realized-volatility-prediction/

# %%
# %pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/1DoZUk_FnkQR4z_AuHH3E7aPqa-ZezMKV/Milestones/optiver-realized-volatility-prediction'

# %%
# %ls
# Out:
# book_test.parquet/   sample_submission.csv  trade_test.parquet/   train.csv
# book_train.parquet/  test.csv               trade_train.parquet/

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
stock_id = '0'

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

book_train_stock0 = pd.read_parquet('book_train.parquet/stock_id=' + stock_id)
book_test_stock0 = pd.read_parquet('book_test.parquet/stock_id=0')

trade_train_stock0 = pd.read_parquet('trade_train.parquet/stock_id=' + stock_id)
trade_test_stock0 = pd.read_parquet('trade_test.parquet/stock_id=0')

# %% [markdown]
# ### Tutorial Notebook Imports

# %%
book_example = book_train_stock0
trade_example = trade_train_stock0

# %%
book_example = book_example[book_example['time_id']==5]
book_example.loc[:,'stock_id'] = stock_id
trade_example = trade_example[trade_example['time_id']==5]
trade_example.loc[:,'stock_id'] = stock_id
# Out:
# <ipython-input-8-43f217f17e6b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_example.loc[:,'stock_id'] = stock_id
# <ipython-input-8-43f217f17e6b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_example.loc[:,'stock_id'] = stock_id

# %%
book_example.head()
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.001422    1.002301     1.00137    1.002353
# 1        5                  1    1.001422    1.002301     1.00137    1.002353
# 2        5                  5    1.001422    1.002301     1.00137    1.002405
# 3        5                  6    1.001422    1.002301     1.00137    1.002405
# 4        5                  7    1.001422    1.002301     1.00137    1.002405
#
#    bid_size1  ask_size1  bid_size2  ask_size2 stock_id
# 0          3        226          2        100        0
# 1          3        100          2        100        0
# 2          3        100          2        100        0
# 3          3        126          2        100        0
# 4          3        126          2        100        0

# %%
trade_example.head()
# Out:
#    time_id  seconds_in_bucket     price  size  order_count stock_id
# 0        5                 21  1.002301   326           12        0
# 1        5                 46  1.002778   128            4        0
# 2        5                 50  1.002818    55            1        0
# 3        5                 57  1.003155   121            5        0
# 4        5                 68  1.003646     4            1        0

# %%
book_example['wap'] = (book_example['bid_price1'] * book_example['ask_size1'] +
                                book_example['ask_price1'] * book_example['bid_size1']) / (
                                       book_example['bid_size1']+ book_example['ask_size1'])
# Out:
# <ipython-input-11-e99ed998be73>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_example['wap'] = (book_example['bid_price1'] * book_example['ask_size1'] +

# %%
fig = px.line(book_example, x="seconds_in_bucket", y="wap", title='WAP of stock_id_0, time_id_5')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def log_return(list_stock_prices):
    return np.log(list_stock_prices).diff()

# %%
book_example.loc[:,'log_return'] = log_return(book_example['wap'])
book_example = book_example[~book_example['log_return'].isnull()]
# Out:
# <ipython-input-14-eb0a6f5295cf>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.line(book_example, x="seconds_in_bucket", y="log_return", title='Log return of stock_id_0, time_id_5')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def realized_volatility(series_log_return):
    return np.sqrt(np.sum(series_log_return**2))
realized_vol = realized_volatility(book_example['log_return'])
print(f'Realized volatility for stock_id 0 on time_id 5 is {realized_vol}')
# Out:
# Realized volatility for stock_id 0 on time_id 5 is 0.004499364172786558

# %%
import os
from sklearn.metrics import r2_score
import glob
list_order_book_file_train = glob.glob('book_train.parquet/*')

# %%
list_order_book_file_train

# %%
def realized_volatility_per_time_id(file_path, prediction_column_name):
    df_book_data = pd.read_parquet(file_path)
    df_book_data['wap'] =(df_book_data['bid_price1'] * df_book_data['ask_size1']+df_book_data['ask_price1'] * df_book_data['bid_size1'])  / (
                                      df_book_data['bid_size1']+ df_book_data[
                                  'ask_size1'])
    df_book_data['log_return'] = df_book_data.groupby(['time_id'])['wap'].apply(log_return)
    df_book_data = df_book_data[~df_book_data['log_return'].isnull()]
    df_realized_vol_per_stock =  pd.DataFrame(df_book_data.groupby(['time_id'])['log_return'].agg(realized_volatility)).reset_index()
    df_realized_vol_per_stock = df_realized_vol_per_stock.rename(columns = {'log_return':prediction_column_name})
    stock_id = file_path.split('=')[1]
    df_realized_vol_per_stock['row_id'] = df_realized_vol_per_stock['time_id'].apply(lambda x:f'{stock_id}-{x}')
    return df_realized_vol_per_stock[['row_id',prediction_column_name]]

# %%
def past_realized_volatility_per_stock(list_file,prediction_column_name):
    df_past_realized = pd.DataFrame()
    for file in list_file:
        df_past_realized = pd.concat([df_past_realized,
                                     realized_volatility_per_time_id(file,prediction_column_name)])
    return df_past_realized
df_past_realized_train = past_realized_volatility_per_stock(list_file=list_order_book_file_train,
                                                           prediction_column_name='pred')

# %%
train['row_id'] = train['stock_id'].astype(str) + '-' + train['time_id'].astype(str)
train = train[['row_id','target']]
df_joined = train.merge(df_past_realized_train[['row_id','pred']], on = ['row_id'], how = 'left')

# %%
from sklearn.metrics import r2_score
def rmspe(y_true, y_pred):
    return  (np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))))
R2 = round(r2_score(y_true = df_joined['target'], y_pred = df_joined['pred']),3)
RMSPE = round(rmspe(y_true = df_joined['target'], y_pred = df_joined['pred']),3)
print(f'Performance of the naive prediction: R2 score: {R2}, RMSPE: {RMSPE}')
# Out:
# Performance of the naive prediction: R2 score: 0.628, RMSPE: 0.341
